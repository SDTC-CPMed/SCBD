# %%
import gzip
#import mitosheet
#mitosheet.sheet()
import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
variant_disease = pd.read_csv("all_variant_disease_associations.tsv.gz", compression='gzip', sep = '\t')

# %%
print(np.shape(np.unique(variant_disease['diseaseName'])))
np.unique(variant_disease['diseaseName'])
# Out:
# (14155,)
# array(['1-3 toe syndactyly', '1-5 finger syndactyly', '11 pairs of ribs',
#        ..., 'von Willebrand disease type 2M',
#        "von Willebrand's factor (lab test)", 'winter depression'],
#       dtype=object)

# %%
variant_disease
# Out:
#                snpId chromosome   position    DSI   DPI diseaseId  \
# 0          rs1000005         21   33060745    NaN   NaN  C0200638
# 1         rs10000770          4  142693109  1.000  0.04  C0023467
# 2       rs1000091588         11   68935374  1.000  0.12  C1858517
# 3          rs1000096          4   38691214    NaN   NaN  C1305855
# 4         rs10001106          4   10125817  0.925  0.12  C0003868
# ...              ...        ...        ...    ...   ...       ...
# 369549   rs999947969          7   80671145  0.827  0.08  C0155626
# 369550   rs999947969          7   80671145  0.827  0.08  C1956346
# 369551     rs9999653          4   55632082  1.000  0.08  C2362324
# 369552     rs9999820          4  155197173  0.925  0.08  C0025322
# 369553     rs9999820          4  155197173  0.925  0.08  C0085215
#
#                                               diseaseName diseaseType  \
# 0                              Eosinophil count procedure   phenotype
# 1                             Leukemia, Myelocytic, Acute     disease
# 2       SPINAL MUSCULAR ATROPHY WITH RESPIRATORY DISTR...     disease
# 3                                         Body mass index   phenotype
# 4                                        Arthritis, Gouty     disease
# ...                                                   ...         ...
# 369549                        Acute myocardial infarction     disease
# 369550                            Coronary Artery Disease     disease
# 369551                                  Pediatric Obesity     disease
# 369552                                Premature Menopause     disease
# 369553                         Ovarian Failure, Premature     disease
#
#        diseaseClass   diseaseSemanticType  score   EI  YearInitial  YearFinal  \
# 0               NaN  Laboratory Procedure   0.70  1.0       2016.0     2016.0
# 1               C04    Neoplastic Process   0.70  1.0       2017.0     2017.0
# 2       C16;C08;C10   Disease or Syndrome   0.70  1.0       2007.0     2007.0
# 3               NaN    Clinical Attribute   0.70  1.0       2019.0     2019.0
# 4       C16;C18;C05   Disease or Syndrome   0.70  1.0       2010.0     2013.0
# ...             ...                   ...    ...  ...          ...        ...
# 369549      C23;C14   Disease or Syndrome   0.01  0.0       2012.0     2012.0
# 369550          C14   Disease or Syndrome   0.01  0.0       2007.0     2007.0
# 369551      C23;C18   Disease or Syndrome   0.01  1.0       2017.0     2017.0
# 369552          C13   Disease or Syndrome   0.01  1.0       2018.0     2018.0
# 369553      C13;C19   Disease or Syndrome   0.70  1.0       2018.0     2018.0
#
#         NofPmids            source
# 0              1  GWASCAT;INFERRED
# 1              1  GWASCAT;INFERRED
# 2              1  CLINVAR;INFERRED
# 3              1  GWASCAT;INFERRED
# 4              3   GWASDB;INFERRED
# ...          ...               ...
# 369549         1            BEFREE
# 369550         1            BEFREE
# 369551         1            BEFREE
# 369552         1            BEFREE
# 369553         1  GWASCAT;INFERRED
#
# [369554 rows x 16 columns]

# %%
Breast = list()
for i in range(len(variant_disease['diseaseName'])):
    if 'Breast' in variant_disease['diseaseName'][i] and 'Atypical Ductal Breast Hyperplasia' not in variant_disease['diseaseName'][i] \
        and 'Breast Diffuse Large B-Cell Lymphoma' not in variant_disease['diseaseName'][i] \
        and 'Breast Diseases' not in variant_disease['diseaseName'][i] \
        and 'Breast Fibrocystic Disease' not in variant_disease['diseaseName'][i] \
        and 'Breast size' not in variant_disease['diseaseName'][i] \
        and 'Columnar Cell Change of the Breast' not in variant_disease['diseaseName'][i] \
        and 'Columnar Cell Hyperplasia of the Breast' not in variant_disease['diseaseName'][i] \
        and 'Mammographic Breast Density' not in variant_disease['diseaseName'][i] \
        and 'Zinc Deficiency, Neonatal, due to Low Breast Milk Zinc' not in variant_disease['diseaseName'][i]:
        Breast.append(i)
    if 'breast' in variant_disease['diseaseName'][i] :
        Breast.append(i)

print(len(np.unique(variant_disease['diseaseName'][Breast])))
np.unique(variant_disease['diseaseName'][Breast])
# Out:
# 59
# array(['Advanced breast cancer',
#        'Anatomic Stage II Breast Cancer AJCC v8',
#        'Anatomic Stage III Breast Cancer AJCC v8',
#        'Basal-Like Breast Carcinoma', 'Breast Cancer, Familial',
#        'Breast Carcinoma', 'Breast adenocarcinoma',
#        'Breast cancer stage II', 'Breast cancer stage III',
#        'Breast cancer, lobular', 'Carcinoma breast stage IV',
#        'Carcinoma of Male Breast', 'Contralateral breast cancer',
#        'Ductal Breast Carcinoma', 'Early-Stage Breast Carcinoma',
#        'Female Breast Carcinoma', 'HER-2 positive breast cancer',
#        'HER2-negative breast cancer', 'HER2-positive carcinoma of breast',
#        'Hereditary Breast and Ovarian Cancer Syndrome',
#        'Infiltrating duct carcinoma of female breast',
#        'Intermediate Grade Ductal Breast Carcinoma In Situ',
#        'Invasive Ductal Breast Carcinoma', 'Invasive carcinoma of breast',
#        'Lobular carcinoma in situ of breast',
#        'Locally advanced breast cancer', 'Luminal A Breast Carcinoma',
#        'Luminal B Breast Carcinoma', 'Malignant melanoma of breast',
#        'Malignant neoplasm of breast',
#        'Malignant neoplasm of female breast',
#        'Malignant neoplasm of male breast',
#        'Malignant phyllodes tumor of breast',
#        'Medullary carcinoma of breast', 'Metastatic Breast Carcinoma',
#        'Multifocal breast carcinoma', 'Node-negative breast cancer',
#        'Node-positive breast cancer',
#        'Oestrogen receptor positive breast cancer',
#        'Premenopausal breast cancer',
#        'Prognostic Stage II Breast Cancer AJCC v8',
#        'Prognostic Stage III Breast Cancer AJCC v8',
#        'Secondary malignant neoplasm of female breast',
#        'Sporadic Breast Carcinoma',
#        'Stage 0 Breast Cancer AJCC v6 and v7', 'Stage 0 Breast Carcinoma',
#        'Stage II Breast Cancer AJCC v6 and v7',
#        'Stage III Breast Cancer AJCC v6',
#        'Stage III Breast Cancer AJCC v7',
#        'Triple Negative Breast Neoplasms',
#        'Triple-Negative Breast Cancer Finding',
#        'Triple-Negative Breast Carcinoma', 'Unilateral Breast Carcinoma',
#        'Unilateral Breast Neoplasms', 'bilateral breast cancer',
#        'estrogen receptor-negative breast cancer',
#        'malignant neoplasm of breast staging',
#        'progesterone receptor-negative breast cancer',
#        'progesterone receptor-positive breast cancer'], dtype=object)

# %%
#These are information about the diseases from the database
variant_disease.loc[Breast]
# Out:
#              snpId chromosome  position    DSI   DPI diseaseId  \
# 152      rs1001179         11  34438684  0.641  0.68  C0006142
# 176      rs1001179         11  34438684  0.641  0.68  C0678222
# 191        rs10012          2  38075247  0.716  0.28  C0006142
# 201        rs10012          2  38075247  0.716  0.28  C0678222
# 334     rs10022462          4  88322666  1.000  0.08  C0678222
# ...            ...        ...       ...    ...   ...       ...
# 369507    rs999737         14  68567965  0.776  0.20  C0235653
# 369508    rs999737         14  68567965  0.776  0.20  C0242787
# 369509    rs999737         14  68567965  0.776  0.20  C0678222
# 369511    rs999737         14  68567965  0.776  0.20  C3539878
# 369512    rs999737         14  68567965  0.776  0.20  C4722518
#
#                                 diseaseName diseaseType diseaseClass  \
# 152            Malignant neoplasm of breast     disease      C04;C17
# 176                        Breast Carcinoma     disease      C04;C17
# 191            Malignant neoplasm of breast     disease      C04;C17
# 201                        Breast Carcinoma     disease      C04;C17
# 334                        Breast Carcinoma     disease      C04;C17
# ...                                     ...         ...          ...
# 369507  Malignant neoplasm of female breast     disease      C04;C17
# 369508    Malignant neoplasm of male breast     disease  C04;C17;C19
# 369509                     Breast Carcinoma     disease      C04;C17
# 369511     Triple Negative Breast Neoplasms     disease      C04;C17
# 369512     Triple-Negative Breast Carcinoma     disease      C04;C17
#
#        diseaseSemanticType  score        EI  YearInitial  YearFinal  NofPmids  \
# 152     Neoplastic Process   0.02  1.000000       2012.0     2016.0         2
# 176     Neoplastic Process   0.02  1.000000       2012.0     2016.0         2
# 191     Neoplastic Process   0.03  0.666667       2009.0     2015.0         3
# 201     Neoplastic Process   0.03  0.666667       2009.0     2015.0         3
# 334     Neoplastic Process   0.70  1.000000       2017.0     2017.0         1
# ...                    ...    ...       ...          ...        ...       ...
# 369507  Neoplastic Process   0.01  1.000000       2016.0     2016.0         1
# 369508  Neoplastic Process   0.01  1.000000       2016.0     2016.0         1
# 369509  Neoplastic Process   0.77  0.909091       2009.0     2017.0        11
# 369511  Neoplastic Process   0.01  1.000000       2011.0     2011.0         1
# 369512  Neoplastic Process   0.01  1.000000       2011.0     2011.0         1
#
#                          source
# 152                      BEFREE
# 176                      BEFREE
# 191                      BEFREE
# 201                      BEFREE
# 334            GWASCAT;INFERRED
# ...                         ...
# 369507                   BEFREE
# 369508                   BEFREE
# 369509  BEFREE;GWASCAT;INFERRED
# 369511                   BEFREE
# 369512                   BEFREE
#
# [9149 rows x 16 columns]

# %%
#Map the database to the geneSymbol names
snpId = variant_disease.loc[Breast]['snpId']
variant_gene = pd.read_csv("variant_to_gene_mappings.tsv.gz", compression='gzip', sep = '\t')
chosen = list()
for i in range(len(variant_gene['snpId'])):
    if variant_gene['snpId'][i] in np.array(snpId):
        chosen.append(i)
variant_gene.loc[chosen]

# Here is the list of GWAS genes that we are interested in
GWAS_Breast = np.unique(variant_gene.loc[chosen]['geneSymbol'])
print(len(GWAS_Breast))
# Out:
# 1697

# %%
'''GWAS enrichment'''
'''DEGs are selected DSs'''
    
#DEGs of each celltype 
cancer_list = ['Lung','Liver','Breast','Colon','Ovary']
cancer = "Breast" # change here for different cancers

with open('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/GWAS/2022Mar09/GWAS_enrich_percelltype_'+cancer+'.txt','w') as f:

    DEGs = pd.read_csv('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/MCDM/Ligand_target_allDS_of_allUR/ligand_target_merged_withFC.csv',sep = ',')
    DEGs = DEGs.loc[DEGs['cancer']==cancer]
    DEGs

    celltype_DEG = np.unique(DEGs['receiver'])
    print("celltypes_DEGs: ", celltype_DEG, file =f)

    '''all_genes means the combine of all background genes in all celltypes'''
    bg_file_path = ("/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/DEGs/Background_genes/background_genes_"+cancer+".csv")
    all_gene = np.arange(0)
    all = pd.read_csv(bg_file_path,sep = ',') 
    all = all.drop('Unnamed: 0',axis = 1)

    celltype_bg = all.columns
    print("celltypes_bgs: ", celltype_bg, file =f)
    DEGs

    '''for Breast only - loop all celltype'''
    for c in range(len(celltype_DEG)):
        print('\n', file =f)
        print(celltype_DEG[c], file =f)
        iDEGs = DEGs.loc[DEGs['receiver']==celltype_DEG[c]]['target'].unique()
        print(celltype_DEG[c],"DEGs",len(iDEGs), file =f)
        ibackground_genes = all[celltype_DEG[c]].unique()
        ibackground_genes = [x for x in ibackground_genes if x != 'NAN']
        ibackground_genes = [x for x in ibackground_genes if x != 'nan']
        print(celltype_DEG[c],"background",len(ibackground_genes), file =f)

        GWAS = list()
        for g in GWAS_Breast:
            for a in ibackground_genes:
                a = str(a)
                for i in range(len(a.split('///'))):
                    if g == a.split('///')[i]:
                        GWAS.append(a)                   
        GWAS = np.unique(GWAS)
        GWAS

        nonDEGs = list(set(ibackground_genes) - set(iDEGs))                
        table11 = len(np.intersect1d(GWAS, iDEGs))
        table12 = len(iDEGs) - table11
        table21 = len(np.intersect1d(GWAS, nonDEGs))
        table22 = len(ibackground_genes) - (table21 + table12 + table11)
        table = pd.DataFrame([[table11, table12], [table21, table22]])
        table.index = ('DEGs', 'nonDEGs')
        table.columns = ('GWAS', 'nonGWAS')

        print('Breast Cancer - ',celltype_DEG[c], file =f )
        print(table, file =f)
        odds, pval = stats.fisher_exact(table)
        print("Odds ratio: ", round(odds, 4), file =f)
        print("p-value: ",round(pval, 6), file =f)

        # if the odds are > 1 and pval <0.05 The list of DEGs is significantly enriched by the GWAS genes
        # if the odds are < 1 and pval <0.05 The list of DEGs is not enriched by the GWAS genes

# %%
'''GWAS enrichment'''
'''DEGs are selected all DSs
    background genes are all differentially expressed genes
'''
    
#DEGs of each celltype 
cancer_list = ['Lung','Liver','Breast','Colon','Ovary']
cancer = "Breast" # change here for different cancers

with open('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/GWAS/2022Mar09/GWAS_enrich_percelltype_DEGasBG_'+cancer+'.txt','w') as f:

    DEGs = pd.read_csv('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/MCDM/Ligand_target_allDS_of_allUR/ligand_target_merged_withFC.csv',sep = ',')
    DEGs = DEGs.loc[DEGs['cancer']==cancer]
    DEGs

    celltype_DEG = np.unique(DEGs['receiver'])
    print("celltypes_DEGs: ", celltype_DEG, file =f)

    '''Differentially expressed genes in each cell type were background genes'''
    bg_file_path = ("/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/DEGs/DEGs_of_"+cancer+"/DEGs_merged_"+cancer+"_MAST.txt")
    all_gene = np.arange(0)
    all = pd.read_csv(bg_file_path,sep = '\t') 
    all
    
    celltype_bg = all.columns
    print("celltypes_bgs: ", celltype_bg, file =f)
    DEGs

    '''loop all celltype'''
    for c in range(len(celltype_DEG)):
        print('\n', file =f)
        print(celltype_DEG[c], file =f)
        iDEGs = DEGs.loc[DEGs['receiver']==celltype_DEG[c]]['target'].unique()
        print(celltype_DEG[c],"DEGs",len(iDEGs), file =f)
        ibackground_genes = all[celltype_DEG[c]].unique()
        ibackground_genes = [x for x in ibackground_genes if x != 'NAN']
        ibackground_genes = [x for x in ibackground_genes if x != 'nan']
        print(celltype_DEG[c],"background",len(ibackground_genes), file =f)

        GWAS = list()
        for g in GWAS_Breast:
            for a in ibackground_genes:
                a = str(a)
                for i in range(len(a.split('///'))):
                    if g == a.split('///')[i]:
                        GWAS.append(a)                   
        GWAS = np.unique(GWAS)
        GWAS

        nonDEGs = list(set(ibackground_genes) - set(iDEGs))                
        table11 = len(np.intersect1d(GWAS, iDEGs))
        table12 = len(iDEGs) - table11
        table21 = len(np.intersect1d(GWAS, nonDEGs))
        table22 = len(ibackground_genes) - (table21 + table12 + table11)
        table = pd.DataFrame([[table11, table12], [table21, table22]])
        table.index = ('DEGs', 'nonDEGs')
        table.columns = ('GWAS', 'nonGWAS')

        print('Breast Cancer - ',celltype_DEG[c], file =f )
        print(table, file =f)
        odds, pval = stats.fisher_exact(table)
        print("Odds ratio: ", round(odds, 4), file =f)
        print("p-value: ",round(pval, 6), file =f)

        # if the odds are > 1 and pval <0.05 The list of DEGs is significantly enriched by the GWAS genes
        # if the odds are < 1 and pval <0.05 The list of DEGs is not enriched by the GWAS genes

# %%
# list GWAS gene that in our gene-of-interests
np.intersect1d(GWAS, DEGs)
# Out:
# array(['ALDH1A1', 'BAX', 'CCND1', 'COL18A1', 'COL1A1', 'FN1', 'GNAS',
#        'KRT8', 'MMP2', 'MMP9', 'MUC1', 'NFKBIA', 'NR3C1', 'RUNX1', 'SHC1',
#        'SPP1', 'TGFB1', 'ZFP36'], dtype=object)

# %%
'''GWAS enrichment'''
'''DEGs are selected all DSs of the top scURs
    background genes are all differentially expressed genes
'''
    
#DEGs of each celltype 
cancer_list = ['Lung','Liver','Breast','Colon','Ovary']
cancer = "Breast" # change here for different cancers

with open('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/GWAS/2022Mar09/GWAS_enrich_percelltype_DS4topscUR_DEGasBG_'+cancer+'.txt','w') as f:

    DEGs = pd.read_csv('/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/MCDM/ligand_target_merged_DS_of_scUR.csv',sep = ',')
    top_scURs = ["COL1A1","FN1","SPP1","COL4A1","COL18A1", "PLAU" , "CLEC11A" ,"MDK"]
    DEGs = DEGs.loc[np.isin(DEGs['ligand'], top_scURs)]
    DEGs = DEGs.loc[DEGs['cancer']==cancer]

    celltype_DEG = np.unique(DEGs['receiver'])
    print("celltypes_DEGs: ", celltype_DEG, file =f)

    '''Differentially expressed genes in each cell type were background genes'''
    bg_file_path = ("/Users/cynthia_ye/Documents/OneDrive - Linköpings universitet/cancer/datafile/outputs_5cancers/new_outputs/DEGs/DEGs_of_"+cancer+"/DEGs_merged_"+cancer+"_MAST.txt")
    all_gene = np.arange(0)
    all = pd.read_csv(bg_file_path,sep = '\t') 
    all
    
    celltype_bg = all.columns
    print("celltypes_bgs: ", celltype_bg, file =f)
    DEGs

    '''loop all celltype'''
    for c in range(len(celltype_DEG)):
        print('\n', file =f)
        print(celltype_DEG[c], file =f)
        iDEGs = DEGs.loc[DEGs['receiver']==celltype_DEG[c]]['target'].unique()
        print(celltype_DEG[c],"DEGs",len(iDEGs), file =f)
        ibackground_genes = all[celltype_DEG[c]].unique()
        ibackground_genes = [x for x in ibackground_genes if x != 'NAN']
        ibackground_genes = [x for x in ibackground_genes if x != 'nan']
        print(celltype_DEG[c],"background",len(ibackground_genes), file =f)

        GWAS = list()
        for g in GWAS_Breast:
            for a in ibackground_genes:
                a = str(a)
                for i in range(len(a.split('///'))):
                    if g == a.split('///')[i]:
                        GWAS.append(a)                   
        GWAS = np.unique(GWAS)
        GWAS

        nonDEGs = list(set(ibackground_genes) - set(iDEGs))                
        table11 = len(np.intersect1d(GWAS, iDEGs))
        table12 = len(iDEGs) - table11
        table21 = len(np.intersect1d(GWAS, nonDEGs))
        table22 = len(ibackground_genes) - (table21 + table12 + table11)
        table = pd.DataFrame([[table11, table12], [table21, table22]])
        table.index = ('DEGs', 'nonDEGs')
        table.columns = ('GWAS', 'nonGWAS')

        print('Breast Cancer - ',celltype_DEG[c], file =f )
        print(table, file =f)
        odds, pval = stats.fisher_exact(table)
        print("Odds ratio: ", round(odds, 4), file =f)
        print("p-value: ",round(pval, 6), file =f)

        # if the odds are > 1 and pval <0.05 The list of DEGs is significantly enriched by the GWAS genes
        # if the odds are < 1 and pval <0.05 The list of DEGs is not enriched by the GWAS genes
